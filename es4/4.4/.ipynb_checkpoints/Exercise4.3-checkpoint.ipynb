# %% [markdown]
# ### Exercise 04.3
#
# <span style="color:red">Include the calculation of the pressure, $P$, inside your Molecular Dynamics code</span>: istantaneous values, average values and uncertainties.
#
# Remember that, via the **virial theorem**, the pressure in a Lennard-Jones system can be estimated by means of:
#
# $$ P = \rho k_B T + \frac{1}{3V} \left\langle \sum_{i=1}^{N-1} \sum_{j\,(>i)}^N 48\epsilon \left[ \left(\frac{\sigma}{|\vec{r}_i -\vec{r}_j|}\right)^{12} -
# \frac{1}{2} \left(\frac{\sigma}{|\vec{r}_i -\vec{r}_j|}\right)^6 \right] \right\rangle $$

# %% [markdown]
# Il programma scritto è idantico a quello usato per l'esercizio 4.2. E' stato aggiunto il calcolo della pressione istantanea che viene salvata su un file utilizzato poi per fare il datablocking.
#
# I grafici qui sotto provengono dalla simulazione di un solido equilibrata:

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
Etot = np.loadtxt("./code/risultati/output_etot.dat")
Epot = np.loadtxt("./code/risultati/output_epot.dat")
Ekin = np.loadtxt("./code/risultati/output_ekin.dat")
Temp = np.loadtxt("./code/risultati/output_temp.dat")
Pres = np.loadtxt("./code/risultati/output_pres.dat")

plt.plot(Temp, '.-', markersize=2, label="Temperature" )
plt.plot(Epot, '.-', markersize=2, label="Potential Energy" )
plt.plot(Ekin, '.-', markersize=2, label="Kinetic Energy")
plt.plot(Etot, '.-', markersize=2, label="Total Energy" )
plt.legend()
plt.xlabel("time step")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(Pres, '.-', markersize=2 )
plt.xlabel("time step")
plt.ylabel("P")
plt.title("Istantaneous Pressure")
plt.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

er=1

x, f, error = np.loadtxt("./code/risultati/ave_pres.dat", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(x,f,yerr=error, errorevery=er, elinewidth=1, capsize=1, ms=3)
plt.xlabel('Numers of block')
plt.ylabel('P')
plt.title("Data Blocking: Pressure")
plt.grid(True)

plt.tight_layout()
plt.show()
